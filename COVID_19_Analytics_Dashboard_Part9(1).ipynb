# %%
# COVID-19 Analytics Dashboard
## Part 9 - Sweetviz Automated EDA

# %%
import pandas as pd
import sweetviz as sv

df=pd.read_csv('covid19_newdataset.csv')
print('Shape:',df.shape)
display(df.head())
# Out:
# Shape: (15020, 21)
#          Date Country Continent  Population  New_Cases  Total_Cases  \
# 0  2020-01-01   India      Asia  1278642419        699          699
# 1  2020-01-02   India      Asia  1278642419        982         1681
# 2  2020-01-03   India      Asia  1278642419        102         1783
# 3  2020-01-04   India      Asia  1278642419        955         2738
# 4  2020-01-05   India      Asia  1278642419        929         3667
#
#    New_Deaths  Total_Deaths  New_Recovered  Total_Recovered  ...  \
# 0          10            10            533              533  ...
# 1          31            41            939             1472  ...
# 2           1            42             98             1570  ...
# 3          26            68            752             2322  ...
# 4          12            80            836             3158  ...
#
#    New_Vaccinations  Total_Vaccinations  Vaccination_Rate  New_Tests  \
# 0              5574                5574               0.0      10485
# ...

# %%
print(df.info())
display(df.describe(include='all'))
display(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15020 entries, 0 to 15019
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                15020 non-null  object
#  1   Country             15020 non-null  object
#  2   Continent           15020 non-null  object
#  3   Population          15020 non-null  int64
#  4   New_Cases           15020 non-null  int64
#  5   Total_Cases         15020 non-null  int64
#  6   New_Deaths          15020 non-null  int64
#  7   Total_Deaths        15020 non-null  int64
#  8   New_Recovered       15020 non-null  int64
#  9   Total_Recovered     15020 non-null  int64
#  10  Active_Cases        15020 non-null  int64
#  11  New_Vaccinations    15020 non-null  int64
#  12  Total_Vaccinations  15020 non-null  int64
#  13  Vaccination_Rate    14720 non-null  float64
#  14  New_Tests           15020 non-null  int64
# ...

# %%
report=sv.analyze(df)
report.show_html("COVID19_Sweetviz_Report.html")
print('Report generated successfully.')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report COVID19_Sweetviz_Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# Report generated successfully.

# %%
num=df.select_dtypes(include='number')
display(num.corr())
display(num.cov())
missing=(df.isnull().sum()/len(df))*100
display(missing.sort_values(ascending=False))

# %% [markdown]
# ### Part 9 Completed
# Generated Sweetviz report and statistical analysis.
